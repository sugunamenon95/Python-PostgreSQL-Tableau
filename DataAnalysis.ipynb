# %% [markdown]
# ### Task 1

# %% [markdown]
# #### Import required libraries

# %%
import json
import pandas as pd
import urllib.request
import urllib
import requests
from datetime import date as dt
import psycopg2
from sqlalchemy import create_engine

# %% [markdown]
# #### Import the JSON file

# %%
path = './Downloads/data-analyst-challenge-master/data-analyst-challenge-master/orders.json' # To be updated before execution
f = open(path,)
data = json.load(f)

# %%
data
# Out:
# [{'id': 8369263756632563,
#   'customer': {'id': 47178,
#    'name': 'William Doe',
#    'email': 'william.doe@gmail.com'},
#   'total_price': 79.39,
#   'created_at': '2020-03-07T14:31:11Z',
#   'line_items': [{'id': 610448,
#     'product_id': 632910392,
#     'product_sku': 'PPLEPUNCH20-05',
#     'product_name': 'Purple Punch 2.0 Dried Flower',
#     'price': 29.4},
#    {'id': 997208,
#     'product_id': 278266679,
#     'product_sku': 'GPSTASH-01',
#     'product_name': "Grandpa's Stash Dried Flower",
#     'price': 49.99}]},
#  {'id': 7262170348080494,
#   'customer': {'id': 94720,
#    'name': 'Emile Tumson',
#    'email': 'emile.tumson@gmail.com'},
#   'total_price': 86.98,
#   'created_at': '2020-03-01T09:16:30Z',
#   'line_items': [{'id': 997208,
#     'product_id': 278266679,
#     'product_sku': 'GPSTASH-01',
#     'product_name': "Grandpa's Stash Dried Flower",
#     'price': 49.99},
#    {'id': 759658,
#     'product_id': 573794972,
#     'product_sku': 'SAGENSOUR-01',
#     'product_name': 'Sage N Sour Dried Flower',
#     'price': 36.99}]},
#  {'id': 7722055557038194,
#   'customer': {'id': 59933,
#    'name': 'Ethan Jones',
#    'email': 'ethan.jones@gmail.com'},
#   'total_price': 36.99,
#   'created_at': '2020-01-01T09:17:03Z',
#   'line_items': [{'id': 759658,
#     'product_id': 573794972,
#     'product_sku': 'SAGENSOUR-01',
#     'product_name': 'Sage N Sour Dried Flower',
#     'price': 36.99}]},
#  {'id': 4280852170163518,
#   'customer': {'id': 23955,
#    'name': 'Daniel Smith',
#    'email': 'daniel.smith@gmail.com'},
#   'total_price': 55.98,
#   'created_at': '2020-03-10T11:59:46Z',
#   'line_items': [{'id': 317808,
#     'product_id': 477365777,
#     'product_sku': 'GOGPR-07',
#     'product_name': 'Glueberry OG Pre-Rolls',
#     'price': 5.99},
#    {'id': 771854,
#     'product_id': 694165761,
#     'product_sku': 'HYBTINC-03',
#     'product_name': 'Hybrid Blend THC Tincture',
#     'price': 49.99}]},
#  {'id': 5058732129957127,
#   'customer': {'id': 59933,
#    'name': 'Ethan Jones',
#    'email': 'ethan.jones@gmail.com'},
#   'total_price': 309.98,
#   'created_at': '2020-03-15T07:27:24Z',
#   'line_items': [{'id': 604665,
#     'product_id': 510650809,
#     'product_sku': 'PAX-3',
#     'product_name': 'Pax 3 Vaporizer',
#     'price': 259.99},
#    {'id': 997208,
#     'product_id': 278266679,
#     'product_sku': 'GPSTASH-01',
#     'product_name': "Grandpa's Stash Dried Flower",
#     'price': 49.99}]},
#  {'id': 6431399815998774,
#   'customer': {'id': 23955,
#    'name': 'Daniel Smith',
#    'email': 'daniel.smith@gmail.com'},
#   'total_price': 315.97,
#   'created_at': '2020-03-12T07:16:07Z',
#   'line_items': [{'id': 997208,
#     'product_id': 278266679,
#     'product_sku': 'GPSTASH-01',
#     'product_name': "Grandpa's Stash Dried Flower",
#     'price': 49.99},
#    {'id': 317808,
#     'product_id': 477365777,
#     'product_sku': 'GOGPR-07',
#     'product_name': 'Glueberry OG Pre-Rolls',
#     'price': 5.99},
#    {'id': 604665,
#     'product_id': 510650809,
#     'product_sku': 'PAX-3',
#     'product_name': 'Pax 3 Vaporizer',
#     'price': 259.99}]},
#  {'id': 5791957346866373,
#   'customer': {'id': 47178,
#    'name': 'William Doe',
#    'email': 'william.doe@gmail.com'},
#   'total_price': 36.99,
#   'created_at': '2020-03-24T09:52:40Z',
#   'line_items': [{'id': 759658,
#     'product_id': 573794972,
#     'product_sku': 'SAGENSOUR-01',
#     'product_name': 'Sage N Sour Dried Flower',
#     'price': 36.99}]},
#  {'id': 2079640804901496,
#   'customer': {'id': 23955,
#    'name': 'Daniel Smith',
#    'email': 'daniel.smith@gmail.com'},
#   'total_price': 55.98,
#   'created_at': '2020-02-19T19:33:57Z',
#   'line_items': [{'id': 317808,
#     'product_id': 477365777,
#     'product_sku': 'GOGPR-07',
#     'product_name': 'Glueberry OG Pre-Rolls',
#     'price': 5.99},
#    {'id': 771854,
#     'product_id': 694165761,
#     'product_sku': 'HYBTINC-03',
#     'product_name': 'Hybrid Blend THC Tincture',
#     'price': 49.99}]},
#  {'id': 2249838395290890,
#   'customer': {'id': 47178,
#    'name': 'William Doe',
#    'email': 'william.doe@gmail.com'},
#   'total_price': 309.98,
#   'created_at': '2020-03-13T12:15:51Z',
#   'line_items': [{'id': 604665,
#     'product_id': 510650809,
#     'product_sku': 'PAX-3',
#     'product_name': 'Pax 3 Vaporizer',
#     'price': 259.99},
#    {'id': 997208,
#     'product_id': 278266679,
#     'product_sku': 'GPSTASH-01',
#     'product_name': "Grandpa's Stash Dried Flower",
#     'price': 49.99}]},
#  {'id': 7638742701884072,
#   'customer': {'id': 59933,
#    'name': 'Ethan Jones',
#    'email': 'ethan.jones@gmail.com'},
#   'total_price': 35.39,
#   'created_at': '2020-03-08T05:28:01Z',
#   'line_items': [{'id': 317808,
#     'product_id': 477365777,
#     'product_sku': 'GOGPR-07',
#     'product_name': 'Glueberry OG Pre-Rolls',
#     'price': 5.99},
#    {'id': 610448,
#     'product_id': 632910392,
#     'product_sku': 'PPLEPUNCH20-05',
#     'product_name': 'Purple Punch 2.0 Dried Flower',
#     'price': 29.4}]},
#  {'id': 5307192536865304,
#   'customer': {'id': 47178,
#    'name': 'William Doe',
#    'email': 'william.doe@gmail.com'},
#   'total_price': 86.98,
#   'created_at': '2020-03-12T01:40:57Z',
#   'line_items': [{'id': 997208,
#     'product_id': 278266679,
#     'product_sku': 'GPSTASH-01',
#     'product_name': "Grandpa's Stash Dried Flower",
#     'price': 49.99},
#    {'id': 759658,
#     'product_id': 573794972,
#     'product_sku': 'SAGENSOUR-01',
#     'product_name': 'Sage N Sour Dried Flower',
#     'price': 36.99}]},
#  {'id': 8662976573169716,
#   'customer': {'id': 94720,
#    'name': 'Emile Tumson',
#    'email': 'emile.tumson@gmail.com'},
#   'total_price': 5.99,
#   'created_at': '2020-02-05T10:22:49Z',
#   'line_items': [{'id': 317808,
#     'product_id': 477365777,
#     'product_sku': 'GOGPR-07',
#     'product_name': 'Glueberry OG Pre-Rolls',
#     'price': 5.99}]},
#  {'id': 2366621613260728,
#   'customer': {'id': 23955,
#    'name': 'Daniel Smith',
#    'email': 'daniel.smith@gmail.com'},
#   'total_price': 259.99,
#   'created_at': '2020-01-18T12:46:12Z',
#   'line_items': [{'id': 604665,
#     'product_id': 510650809,
#     'product_sku': 'PAX-3',
#     'product_name': 'Pax 3 Vaporizer',
#     'price': 259.99}]},
#  {'id': 9786845594710809,
#   'customer': {'id': 59933,
#    'name': 'Ethan Jones',
#    'email': 'ethan.jones@gmail.com'},
#   'total_price': 79.39,
#   'created_at': '2020-03-18T13:43:24Z',
#   'line_items': [{'id': 771854,
#     'product_id': 694165761,
#     'product_sku': 'HYBTINC-03',
#     'product_name': 'Hybrid Blend THC Tincture',
#     'price': 49.99},
#    {'id': 610448,
#     'product_id': 632910392,
#     'product_sku': 'PPLEPUNCH20-05',
#     'product_name': 'Purple Punch 2.0 Dried Flower',
#     'price': 29.4}]},
#  {'id': 6255086600405590,
#   'customer': {'id': 94720,
#    'name': 'Emile Tumson',
#    'email': 'emile.tumson@gmail.com'},
#   'total_price': 55.98,
#   'created_at': '2020-01-05T09:41:30Z',
#   'line_items': [{'id': 997208,
#     'product_id': 278266679,
#     'product_sku': 'GPSTASH-01',
#     'product_name': "Grandpa's Stash Dried Flower",
#     'price': 49.99},
#    {'id': 317808,
#     'product_id': 477365777,
#     'product_sku': 'GOGPR-07',
#     'product_name': 'Glueberry OG Pre-Rolls',
#     'price': 5.99}]},
#  {'id': 5235927587417736,
#   'customer': {'id': 94720,
#    'name': 'Emile Tumson',
#    'email': 'emile.tumson@gmail.com'},
#   'total_price': 36.99,
#   'created_at': '2020-03-24T07:12:33Z',
#   'line_items': [{'id': 759658,
#     'product_id': 573794972,
#     'product_sku': 'SAGENSOUR-01',
#     'product_name': 'Sage N Sour Dried Flower',
#     'price': 36.99}]},
#  {'id': 5825547264855968,
#   'customer': {'id': 59933,
#    'name': 'Ethan Jones',
#    'email': 'ethan.jones@gmail.com'},
#   'total_price': 55.98,
#   'created_at': '2020-01-01T12:59:26Z',
#   'line_items': [{'id': 771854,
#     'product_id': 694165761,
#     'product_sku': 'HYBTINC-03',
#     'product_name': 'Hybrid Blend THC Tincture',
#     'price': 49.99},
#    {'id': 317808,
#     'product_id': 477365777,
#     'product_sku': 'GOGPR-07',
#     'product_name': 'Glueberry OG Pre-Rolls',
#     'price': 5.99}]},
#  {'id': 1288301820842508,
#   'customer': {'id': 23955,
#    'name': 'Daniel Smith',
#    'email': 'daniel.smith@gmail.com'},
#   'total_price': 29.4,
#   'created_at': '2020-01-19T03:53:34Z',
#   'line_items': [{'id': 610448,
#     'product_id': 632910392,
#     'product_sku': 'PPLEPUNCH20-05',
#     'product_name': 'Purple Punch 2.0 Dried Flower',
#     'price': 29.4}]},
#  {'id': 1104846479586545,
#   'customer': {'id': 94720,
#    'name': 'Emile Tumson',
#    'email': 'emile.tumson@gmail.com'},
#   'total_price': 86.98,
#   'created_at': '2020-02-22T21:44:05Z',
#   'line_items': [{'id': 997208,
#     'product_id': 278266679,
#     'product_sku': 'GPSTASH-01',
#     'product_name': "Grandpa's Stash Dried Flower",
#     'price': 49.99},
#    {'id': 759658,
#     'product_id': 573794972,
#     'product_sku': 'SAGENSOUR-01',
#     'product_name': 'Sage N Sour Dried Flower',
#     'price': 36.99}]},
#  {'id': 2212383088430312,
#   'customer': {'id': 59933,
#    'name': 'Ethan Jones',
#    'email': 'ethan.jones@gmail.com'},
#   'total_price': 142.96,
#   'created_at': '2020-01-22T21:26:52Z',
#   'line_items': [{'id': 997208,
#     'product_id': 278266679,
#     'product_sku': 'GPSTASH-01',
#     'product_name': "Grandpa's Stash Dried Flower",
#     'price': 49.99},
#    {'id': 759658,
#     'product_id': 573794972,
#     'product_sku': 'SAGENSOUR-01',
#     'product_name': 'Sage N Sour Dried Flower',
#     'price': 36.99},
#    {'id': 317808,
#     'product_id': 477365777,
#     'product_sku': 'GOGPR-07',
#     'product_name': 'Glueberry OG Pre-Rolls',
#     'price': 5.99},
#    {'id': 771854,
#     'product_id': 694165761,
#     'product_sku': 'HYBTINC-03',
#     'product_name': 'Hybrid Blend THC Tincture',
#     'price': 49.99}]}]

# %% [markdown]
# #### Parse the JSON data and store in three dataframes - customer data, order data and order line items

# %%
# The below lists will be combined into a dataframe
# List to store the order IDs
orderID = []
# List to store the total price per order
totalPrice = []
# List to store the order dates 
orderDate = []
# List to store the customer Ids
customerId = []
# Create empty dataframe to store order line items 
orderItem = pd.DataFrame()
# Create empty dataframe to store customer data
customer = pd.DataFrame()
# Loop through each item in json object
for d in data:
    orderID.append(d['id'])
    totalPrice.append(d['total_price'])
    orderDate.append(d['created_at'].split('T')[0])
    customerId.append(d['customer']['id'])
    # Create a list with the order id to be appended with the order line items
    j = [d['id'] for i in range(len(d['line_items']))]
    # Dataframe with the lien items for a specific order with order id as the index
    tempOrder = pd.DataFrame(d['line_items'], index = j)
    orderItem = pd.concat([orderItem, tempOrder])
    # Dataframe to store customer data
    customer = pd.concat([customer, pd.DataFrame(d['customer'], index = [d['id'],])])

# %%
# Combine the lists for OrderId, total price, order date and customer id to form a dataframe for orders. Here customer id acts as a foreign key
orders = pd.DataFrame(list(zip(orderID, totalPrice, orderDate, customerId)), 
               columns =['orderID', 'totalPrice', 'orderDate', 'customerId']) 
# Use index as column OrderId in OrderItem dataframe 
orderItem['orderId'] = orderItem.index

# Reset the index in customer dataframe
customer = customer.reset_index(drop=True)

# %% [markdown]
# #### Get currency exchange rate from API

# %%
# Get the currency exchange for a span of 1 year starting from Aug 1, 2019 to Aug 1, 2020. Base currency is USD and get exchange rate for CAD
base = 'https://api.exchangeratesapi.io/'
currency = '&base=USD&symbols=CAD'

URL = base + 'history?start_at=' + '2019-08-01' + '&end_at=' + '2020-08-01' + currency
response = requests.get(URL)
currency_json = response.json()

# %%
# Create dataframe of the exchange rates for the 1 year duration
date = []
rate = []
for key in currency_json['rates']:
    date.append(key)
    rate.append(currency_json['rates'][key]['CAD'])

exchangeRate = pd.DataFrame(list(zip(date, rate)), 
               columns =['date', 'rate'])

# %%
# Calculate average rate over the 1 year duration. This value will be used to fill missing rates for the orders that
# were placed on weekends/holidays when the market was closed 
rateAvg = exchangeRate['rate'].mean()
rateAvg
# Out:
# 1.345653248287109

# %%
# Merge the exchange rate with orders dataframe on orderdate to get a column for 'rate' in the orders table 
orders = pd.merge(orders, exchangeRate, left_on = 'orderDate', right_on = 'date', how = 'left')
orders['rate'].fillna(rateAvg, inplace=True)

# %%
orders
# Out:
#              orderID  totalPrice   orderDate  customerId        date      rate
# 0   8369263756632563       79.39  2020-03-07       47178         NaN  1.345653
# 1   7262170348080494       86.98  2020-03-01       94720         NaN  1.345653
# 2   7722055557038194       36.99  2020-01-01       59933         NaN  1.345653
# 3   4280852170163518       55.98  2020-03-10       23955  2020-03-10  1.367779
# 4   5058732129957127      309.98  2020-03-15       59933         NaN  1.345653
# 5   6431399815998774      315.97  2020-03-12       23955  2020-03-12  1.381139
# 6   5791957346866373       36.99  2020-03-24       47178  2020-03-24  1.449414
# 7   2079640804901496       55.98  2020-02-19       23955  2020-02-19  1.322315
# 8   2249838395290890      309.98  2020-03-13       47178  2020-03-13  1.385897
# 9   7638742701884072       35.39  2020-03-08       59933         NaN  1.345653
# 10  5307192536865304       86.98  2020-03-12       47178  2020-03-12  1.381139
# 11  8662976573169716        5.99  2020-02-05       94720  2020-02-05  1.328495
# 12  2366621613260728      259.99  2020-01-18       23955         NaN  1.345653
# 13  9786845594710809       79.39  2020-03-18       59933  2020-03-18  1.440369
# 14  6255086600405590       55.98  2020-01-05       94720         NaN  1.345653
# 15  5235927587417736       36.99  2020-03-24       94720  2020-03-24  1.449414
# 16  5825547264855968       55.98  2020-01-01       59933         NaN  1.345653
# 17  1288301820842508       29.40  2020-01-19       23955         NaN  1.345653
# 18  1104846479586545       86.98  2020-02-22       94720         NaN  1.345653
# 19  2212383088430312      142.96  2020-01-22       59933  2020-01-22  1.304563

# %%
customer
# Out:
#        id          name                   email
# 0   47178   William Doe   william.doe@gmail.com
# 1   94720  Emile Tumson  emile.tumson@gmail.com
# 2   59933   Ethan Jones   ethan.jones@gmail.com
# 3   23955  Daniel Smith  daniel.smith@gmail.com
# 4   59933   Ethan Jones   ethan.jones@gmail.com
# 5   23955  Daniel Smith  daniel.smith@gmail.com
# 6   47178   William Doe   william.doe@gmail.com
# 7   23955  Daniel Smith  daniel.smith@gmail.com
# 8   47178   William Doe   william.doe@gmail.com
# 9   59933   Ethan Jones   ethan.jones@gmail.com
# 10  47178   William Doe   william.doe@gmail.com
# 11  94720  Emile Tumson  emile.tumson@gmail.com
# 12  23955  Daniel Smith  daniel.smith@gmail.com
# 13  59933   Ethan Jones   ethan.jones@gmail.com
# 14  94720  Emile Tumson  emile.tumson@gmail.com
# 15  94720  Emile Tumson  emile.tumson@gmail.com
# 16  59933   Ethan Jones   ethan.jones@gmail.com
# 17  23955  Daniel Smith  daniel.smith@gmail.com
# 18  94720  Emile Tumson  emile.tumson@gmail.com
# 19  59933   Ethan Jones   ethan.jones@gmail.com

# %%
orderItem
# Out:
#                       id  product_id     product_sku  \
# 8369263756632563  610448   632910392  PPLEPUNCH20-05
# 8369263756632563  997208   278266679      GPSTASH-01
# 7262170348080494  997208   278266679      GPSTASH-01
# 7262170348080494  759658   573794972    SAGENSOUR-01
# 7722055557038194  759658   573794972    SAGENSOUR-01
# 4280852170163518  317808   477365777        GOGPR-07
# 4280852170163518  771854   694165761      HYBTINC-03
# 5058732129957127  604665   510650809           PAX-3
# 5058732129957127  997208   278266679      GPSTASH-01
# 6431399815998774  997208   278266679      GPSTASH-01
# 6431399815998774  317808   477365777        GOGPR-07
# 6431399815998774  604665   510650809           PAX-3
# 5791957346866373  759658   573794972    SAGENSOUR-01
# 2079640804901496  317808   477365777        GOGPR-07
# 2079640804901496  771854   694165761      HYBTINC-03
# 2249838395290890  604665   510650809           PAX-3
# 2249838395290890  997208   278266679      GPSTASH-01
# 7638742701884072  317808   477365777        GOGPR-07
# 7638742701884072  610448   632910392  PPLEPUNCH20-05
# 5307192536865304  997208   278266679      GPSTASH-01
# 5307192536865304  759658   573794972    SAGENSOUR-01
# 8662976573169716  317808   477365777        GOGPR-07
# 2366621613260728  604665   510650809           PAX-3
# 9786845594710809  771854   694165761      HYBTINC-03
# 9786845594710809  610448   632910392  PPLEPUNCH20-05
# 6255086600405590  997208   278266679      GPSTASH-01
# 6255086600405590  317808   477365777        GOGPR-07
# 5235927587417736  759658   573794972    SAGENSOUR-01
# 5825547264855968  771854   694165761      HYBTINC-03
# 5825547264855968  317808   477365777        GOGPR-07
# 1288301820842508  610448   632910392  PPLEPUNCH20-05
# 1104846479586545  997208   278266679      GPSTASH-01
# 1104846479586545  759658   573794972    SAGENSOUR-01
# 2212383088430312  997208   278266679      GPSTASH-01
# 2212383088430312  759658   573794972    SAGENSOUR-01
# 2212383088430312  317808   477365777        GOGPR-07
# 2212383088430312  771854   694165761      HYBTINC-03
#
#                                    product_name   price           orderId
# 8369263756632563  Purple Punch 2.0 Dried Flower   29.40  8369263756632563
# 8369263756632563   Grandpa's Stash Dried Flower   49.99  8369263756632563
# 7262170348080494   Grandpa's Stash Dried Flower   49.99  7262170348080494
# 7262170348080494       Sage N Sour Dried Flower   36.99  7262170348080494
# 7722055557038194       Sage N Sour Dried Flower   36.99  7722055557038194
# 4280852170163518         Glueberry OG Pre-Rolls    5.99  4280852170163518
# 4280852170163518      Hybrid Blend THC Tincture   49.99  4280852170163518
# 5058732129957127                Pax 3 Vaporizer  259.99  5058732129957127
# 5058732129957127   Grandpa's Stash Dried Flower   49.99  5058732129957127
# 6431399815998774   Grandpa's Stash Dried Flower   49.99  6431399815998774
# 6431399815998774         Glueberry OG Pre-Rolls    5.99  6431399815998774
# 6431399815998774                Pax 3 Vaporizer  259.99  6431399815998774
# 5791957346866373       Sage N Sour Dried Flower   36.99  5791957346866373
# 2079640804901496         Glueberry OG Pre-Rolls    5.99  2079640804901496
# 2079640804901496      Hybrid Blend THC Tincture   49.99  2079640804901496
# 2249838395290890                Pax 3 Vaporizer  259.99  2249838395290890
# 2249838395290890   Grandpa's Stash Dried Flower   49.99  2249838395290890
# 7638742701884072         Glueberry OG Pre-Rolls    5.99  7638742701884072
# 7638742701884072  Purple Punch 2.0 Dried Flower   29.40  7638742701884072
# 5307192536865304   Grandpa's Stash Dried Flower   49.99  5307192536865304
# 5307192536865304       Sage N Sour Dried Flower   36.99  5307192536865304
# 8662976573169716         Glueberry OG Pre-Rolls    5.99  8662976573169716
# 2366621613260728                Pax 3 Vaporizer  259.99  2366621613260728
# 9786845594710809      Hybrid Blend THC Tincture   49.99  9786845594710809
# 9786845594710809  Purple Punch 2.0 Dried Flower   29.40  9786845594710809
# 6255086600405590   Grandpa's Stash Dried Flower   49.99  6255086600405590
# 6255086600405590         Glueberry OG Pre-Rolls    5.99  6255086600405590
# 5235927587417736       Sage N Sour Dried Flower   36.99  5235927587417736
# 5825547264855968      Hybrid Blend THC Tincture   49.99  5825547264855968
# 5825547264855968         Glueberry OG Pre-Rolls    5.99  5825547264855968
# 1288301820842508  Purple Punch 2.0 Dried Flower   29.40  1288301820842508
# 1104846479586545   Grandpa's Stash Dried Flower   49.99  1104846479586545
# 1104846479586545       Sage N Sour Dried Flower   36.99  1104846479586545
# 2212383088430312   Grandpa's Stash Dried Flower   49.99  2212383088430312
# 2212383088430312       Sage N Sour Dried Flower   36.99  2212383088430312
# 2212383088430312         Glueberry OG Pre-Rolls    5.99  2212383088430312
# 2212383088430312      Hybrid Blend THC Tincture   49.99  2212383088430312

# %% [markdown]
# ### Task 2

# %% [markdown]
# The approach I have used below doees not require creating a schema of the table in the database. The table is created at the same time when the data is uploaded. However, the script for creating tables in SQl is as below.
#
# CREATE TABLE public.customer
# (
#     id bigint,
#     name text,
#     email text
# )
#
# CREATE TABLE public.orders
# (
#     orderId bigint,
#     totalPrice int,
#     orderDate date,
#     customerId bigint,
#     rate float
# )
#
# CREATE TABLE public.orderItem
# (
#     orderId bigint,
#     id bigint,
#     productName text,
#     itemPrice float,
#     productId bigint,
#     productSku text
# )

# %% [markdown]
# #### Upload data into PostgreSQL

# %%
# Reusable function to insert data into a table
# Reference: https://pythontic.com/pandas/serialization/postgresql
def insertTable(conn, table, df):
    postgreSQLTable = table;
    try:
        frame = df.to_sql(postgreSQLTable, postgreSQLConnection, if_exists='fail');
    except ValueError as vx:
        print('ValueError', vx)
        
    except Exception as ex:  
        print('exception',ex)
    else:
        print("PostgreSQL Table %s has been created successfully."%postgreSQLTable);

# %%
username = 'postgres'
password = 'sweetshe09'
dbname = 'namasteTech'
alchemyEngine = create_engine('postgresql+psycopg2://'+username+':' + password + '@127.0.0.1/' + dbname, pool_recycle=3600);
postgreSQLConnection = alchemyEngine.connect();
insertTable(postgreSQLConnection, 'orders', orders)
insertTable(postgreSQLConnection, 'customer', customer)
insertTable(postgreSQLConnection, 'orderItem', orderItem)
postgreSQLConnection.close();
# Out:
# PostgreSQL Table orders has been created successfully.
# PostgreSQL Table customer has been created successfully.
# PostgreSQL Table orderItem has been created successfully.

# %% [markdown]
# ### Task 3

# %% [markdown]
# Link to the public dashboard
# https://public.tableau.com/profile/suguna.menon#!/vizhome/NamasteTechnologyAssessment/Ordercountpercustomer?publish=yes
